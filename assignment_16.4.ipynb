# %% [markdown]
# ### 1. Interpretation and significance
#
# Suppose that we would like to know how much families in the US are spending on recreation annually. We've estimated the following model:
#
# $$ expenditure = 873 + 0.0012annual\_income + 0.00002annual\_income^2 - 223.57have\_kids $$
#
# *expenditure* is the annual spending on recreation in US dollars, *annual_income* is the annual income in US dollars, and *have_kids* is a dummy variable indicating the families with children. Interpret the estimated coefficients. What additional statistics should be given in order to make sure that your interpretations make sense statistically. Write up your answer.

# %% [markdown]
# ### Answer 1:
#
# Assuming the coefficients are statistically significant (which we don't know because none of them have their associated statistics reported), we can say that the bias term is $873, the expenditure increases in quadratically with annual income, and families with kids spend 223.57 dollars fewer on recreation.

# %% [markdown]
# ### 2. Weather model
#
# In this exercise, you'll work with the historical temperature data from the previous checkpoint. To complete this assignment, submit a link to a Jupyter notebook containing your solutions to the following tasks:
#
# * First, load the dataset from the **weatherinszeged** table from Thinkful's database.
# * Build a linear regression model where your target variable is the difference between the *apparenttemperature* and the *temperature*. As explanatory variables, use *humidity* and *windspeed*. Now, estimate your model using OLS. Are the estimated coefficients statistically significant? Are the signs of the estimated coefficients in line with your previous expectations? Interpret the estimated coefficients. What are the relations between the target and the explanatory variables?
# * Next, include the interaction of *humidity* and *windspeed* to the model above and estimate the model using OLS. Are the coefficients statistically significant? Did the signs of the estimated coefficients for *humidity* and *windspeed* change? Interpret the estimated coefficients.

# %% [markdown]
# ### Answer 2:

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

import statsmodels.api as sm
import statsmodels.formula.api as smf
from sqlalchemy import create_engine

# Display preferences.
# %matplotlib inline
pd.options.display.float_format = "{:.3f}".format

# %load_ext nb_black

import warnings

warnings.filterwarnings(action="ignore")

# %%
postgres_user = "dsbc_student"
postgres_pw = "7*.8G9QH21"
postgres_host = "142.93.121.174"
postgres_port = "5432"
postgres_db = "weatherinszeged"

engine = create_engine(
    "postgresql://{}:{}@{}:{}/{}".format(
        postgres_user, postgres_pw, postgres_host, postgres_port, postgres_db
    )
)
szeged_df = pd.read_sql_query("select * from weatherinszeged", con=engine)

# no need for an open connection, as we're only doing a single query
engine.dispose()


szeged_df.head(50)
# Out:
#                         date        summary preciptype  temperature  \
# 0  2006-03-31 22:00:00+00:00  Partly Cloudy       rain        9.472
# 1  2006-03-31 23:00:00+00:00  Partly Cloudy       rain        9.356
# 2  2006-04-01 00:00:00+00:00  Mostly Cloudy       rain        9.378
# 3  2006-04-01 01:00:00+00:00  Partly Cloudy       rain        8.289
# 4  2006-04-01 02:00:00+00:00  Mostly Cloudy       rain        8.756
# 5  2006-04-01 03:00:00+00:00  Partly Cloudy       rain        9.222
# 6  2006-04-01 04:00:00+00:00  Partly Cloudy       rain        7.733
# 7  2006-04-01 05:00:00+00:00  Partly Cloudy       rain        8.772
# 8  2006-04-01 06:00:00+00:00  Partly Cloudy       rain       10.822
# 9  2006-04-01 07:00:00+00:00  Partly Cloudy       rain       13.772
# 10 2006-04-01 08:00:00+00:00  Partly Cloudy       rain       16.017
# 11 2006-04-01 09:00:00+00:00  Partly Cloudy       rain       17.144
# 12 2006-04-01 10:00:00+00:00  Partly Cloudy       rain       17.800
# 13 2006-04-01 11:00:00+00:00  Partly Cloudy       rain       17.333
# 14 2006-04-01 12:00:00+00:00  Partly Cloudy       rain       18.878
# 7                 6.528     0.890     14.152      260.000       9.982
# 8                10.822     0.820     11.318      259.000       9.982
# 9                13.772     0.720     12.526      279.000       9.982
# 10               16.017     0.670     17.565      290.000      11.206
# 11               17.144     0.540     19.787      316.000      11.447
# 12               17.800     0.550     21.944      281.000      11.270
# 13               17.333     0.510     20.689      289.000      11.270
# 14               18.878     0.470     15.376      262.000      11.447
# 15               18.911     0.460     10.401      288.000      11.270
# 16               15.389     0.600     14.409      251.000      11.270
# 17               15.550     0.630     11.157      230.000      11.447
# 18               14.256     0.690      8.517      163.000      11.206
# 19               13.144     0.700      7.631      139.000      11.206
# 20               11.550     0.770      7.390      147.000      11.028
# 21               11.183     0.760      4.927      160.000       9.982
# 22               10.117     0.790      6.649      163.000      15.826
# 23               10.200     0.770      3.928      152.000      14.957
# 24               10.422     0.620     16.985      150.000      15.826
# 25                7.567     0.660     17.211      149.000      15.826
# 26               11.183     0.800     10.819      163.000      14.957
# 27                5.044     0.790     11.077      180.000      15.826
# 28                4.817     0.820      6.649      161.000      15.826
# 29                4.272     0.830     13.009      135.000      14.957
# 30                5.156     0.850     11.173      141.000       6.199
# 31                5.528     0.830     12.816      150.000       8.050
# 32                7.933     0.780     13.749      160.000       9.982
# 33               12.222     0.720     15.633      150.000       9.982
# 34               15.094     0.610     17.549      151.000       9.982
# 35               17.356     0.520     22.782      169.000       9.982
# 36               19.006     0.460     23.892      169.000       9.982
# 37               20.044     0.400     28.368      170.000       9.982
# 38               21.050     0.400     26.903      187.000      10.352
# 39               21.183     0.370     25.696      179.000       9.982
# 40               20.117     0.400     25.309      162.000       9.982
# 41               20.217     0.360     18.113      161.000      10.352
# 42               20.000     0.430     23.425      160.000       9.982
# 43               17.800     0.500     20.044      150.000      11.206
# 44               16.061     0.530     21.397      149.000       9.982
# 45               15.022     0.550     21.381      159.000       9.982
# 46               14.422     0.580     20.012      159.000      15.826
# 47               14.256     0.590     16.503      168.000      14.957
# 48               13.772     0.600     17.098      160.000      15.826
# 49               13.283     0.630     14.361      160.000      15.826
#
#     loudcover  pressure                       dailysummary
# 0       0.000  1015.130  Partly cloudy throughout the day.
# 1       0.000  1015.630  Partly cloudy throughout the day.
# 2       0.000  1015.940  Partly cloudy throughout the day.
# 3       0.000  1016.410  Partly cloudy throughout the day.
# 4       0.000  1016.510  Partly cloudy throughout the day.
# 5       0.000  1016.660  Partly cloudy throughout the day.
# 6       0.000  1016.720  Partly cloudy throughout the day.
# 7       0.000  1016.840  Partly cloudy throughout the day.
# 8       0.000  1017.370  Partly cloudy throughout the day.
# 9       0.000  1017.220  Partly cloudy throughout the day.
# 10      0.000  1017.420  Partly cloudy throughout the day.
# 11      0.000  1017.740  Partly cloudy throughout the day.
# 12      0.000  1017.590  Partly cloudy throughout the day.
# 13      0.000  1017.480  Partly cloudy throughout the day.
# 14      0.000  1017.170  Partly cloudy throughout the day.
# 15      0.000  1016.470  Partly cloudy throughout the day.
# 16      0.000  1016.150  Partly cloudy throughout the day.
# 17      0.000  1016.170  Partly cloudy throughout the day.
# 18      0.000  1015.820  Partly cloudy throughout the day.
# 19      0.000  1015.830  Partly cloudy throughout the day.
# 20      0.000  1015.850  Partly cloudy throughout the day.
# 21      0.000  1015.770  Partly cloudy throughout the day.
# 22      0.000  1015.400  Partly cloudy throughout the day.
# 23      0.000  1015.510  Partly cloudy throughout the day.
# 24      0.000  1014.400  Mostly cloudy throughout the day.
# 25      0.000  1014.200  Mostly cloudy throughout the day.
# 26      0.000  1008.710  Mostly cloudy throughout the day.
# 27      0.000  1014.470  Mostly cloudy throughout the day.
# 28      0.000  1014.450  Mostly cloudy throughout the day.
# 29      0.000  1014.490  Mostly cloudy throughout the day.
# 30      0.000  1014.520  Mostly cloudy throughout the day.
# 31      0.000  1014.160  Mostly cloudy throughout the day.
# 32      0.000  1014.240  Mostly cloudy throughout the day.
# 33      0.000  1014.250  Mostly cloudy throughout the day.
# 34      0.000  1013.960  Mostly cloudy throughout the day.
# 35      0.000  1013.850  Mostly cloudy throughout the day.
# 36      0.000  1013.040  Mostly cloudy throughout the day.
# 37      0.000  1012.220  Mostly cloudy throughout the day.
# 38      0.000  1011.440  Mostly cloudy throughout the day.
# 39      0.000  1010.520  Mostly cloudy throughout the day.
# 40      0.000  1009.830  Mostly cloudy throughout the day.
# 41      0.000  1009.260  Mostly cloudy throughout the day.
# 42      0.000  1008.760  Mostly cloudy throughout the day.
# 43      0.000  1008.360  Mostly cloudy throughout the day.
# 44      0.000  1008.110  Mostly cloudy throughout the day.
# 45      0.000  1008.150  Mostly cloudy throughout the day.
# 46      0.000  1007.850  Mostly cloudy throughout the day.
# 47      0.000  1007.890  Mostly cloudy throughout the day.
# 48      0.000  1007.360              Foggy in the evening.
# 49      0.000  1007.260              Foggy in the evening.

# %%
szeged_df.isna().mean()
# Out:
# date                  0.000
# summary               0.000
# preciptype            0.000
# temperature           0.000
# apparenttemperature   0.000
# humidity              0.000
# windspeed             0.000
# windbearing           0.000
# visibility            0.000
# loudcover             0.000
# pressure              0.000
# dailysummary          0.000
# dtype: float64

# %%
szeged_df.describe()
# Out:
#        temperature  apparenttemperature  humidity  windspeed  windbearing  \
# count    96453.000            96453.000 96453.000  96453.000    96453.000
# mean        11.933               10.855     0.735     10.811      187.509
# std          9.552               10.697     0.195      6.914      107.383
# min        -21.822              -27.717     0.000      0.000        0.000
# 25%          4.689                2.311     0.600      5.828      116.000
# 50%         12.000               12.000     0.780      9.966      180.000
# 75%         18.839               18.839     0.890     14.136      290.000
# max         39.906               39.344     1.000     63.853      359.000
#
#        visibility  loudcover  pressure
# count   96453.000  96453.000 96453.000
# mean       10.347      0.000  1003.236
# std         4.192      0.000   116.970
# min         0.000      0.000     0.000
# 25%         8.340      0.000  1011.900
# 50%        10.046      0.000  1016.450
# 75%        14.812      0.000  1021.090
# max        16.100      0.000  1046.380

# %%
szeged_df["target_temp"] = szeged_df["apparenttemperature"] - szeged_df["temperature"]

# %%
szeged_df.describe()
# Out:
#        temperature  apparenttemperature  humidity  windspeed  windbearing  \
# count    96453.000            96453.000 96453.000  96453.000    96453.000
# mean        11.933               10.855     0.735     10.811      187.509
# std          9.552               10.697     0.195      6.914      107.383
# min        -21.822              -27.717     0.000      0.000        0.000
# 25%          4.689                2.311     0.600      5.828      116.000
# 50%         12.000               12.000     0.780      9.966      180.000
# 75%         18.839               18.839     0.890     14.136      290.000
# max         39.906               39.344     1.000     63.853      359.000
#
#        visibility  loudcover  pressure  target_temp
# count   96453.000  96453.000 96453.000    96453.000
# mean       10.347      0.000  1003.236       -1.078
# std         4.192      0.000   116.970        1.679
# min         0.000      0.000     0.000      -10.183
# 25%         8.340      0.000  1011.900       -2.217
# 50%        10.046      0.000  1016.450        0.000
# 75%        14.812      0.000  1021.090        0.000
# max        16.100      0.000  1046.380        4.811

# %%
y = szeged_df["target_temp"]
X = szeged_df[["humidity", "windspeed"]]

# %%
X = sm.add_constant(X)

results = sm.OLS(y, X).fit()

results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            target_temp   R-squared:                       0.288
# Model:                            OLS   Adj. R-squared:                  0.288
# Method:                 Least Squares   F-statistic:                 1.949e+04
# Date:                Tue, 07 Apr 2020   Prob (F-statistic):               0.00
# Time:                        20:37:48   Log-Likelihood:            -1.7046e+05
# No. Observations:               96453   AIC:                         3.409e+05
# Df Residuals:                   96450   BIC:                         3.409e+05
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          2.4381      0.021    115.948      0.000       2.397       2.479
# humidity      -3.0292      0.024   -126.479      0.000      -3.076      -2.982
# windspeed     -0.1193      0.001   -176.164      0.000      -0.121      -0.118
# ==============================================================================
# Omnibus:                     3935.747   Durbin-Watson:                   0.267
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4613.311
# Skew:                          -0.478   Prob(JB):                         0.00
# Kurtosis:                       3.484   Cond. No.                         88.1
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# The coefficients are statistically significant at p < 0.001.  The difference in apparent versus regular temperature (wind chill?), i.e. target_temp, seems to decrease with increase in humidity or windspeed.  For a one unit increase in humidity, the target_temp decreases by 3.03 degrees.  For a one unit increase in windspeed, the target_temp decreases by 0.012 degrees.

# %%
szeged_df["wind_hum_interaction"] = szeged_df["windspeed"] * szeged_df["humidity"]

# %%
y = szeged_df["target_temp"]
X2 = szeged_df[["humidity", "windspeed", "wind_hum_interaction"]]

# %%
X2 = sm.add_constant(X2)

results = sm.OLS(y, X2).fit()

results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            target_temp   R-squared:                       0.341
# Model:                            OLS   Adj. R-squared:                  0.341
# Method:                 Least Squares   F-statistic:                 1.666e+04
# Date:                Tue, 07 Apr 2020   Prob (F-statistic):               0.00
# Time:                        20:55:17   Log-Likelihood:            -1.6669e+05
# No. Observations:               96453   AIC:                         3.334e+05
# Df Residuals:                   96449   BIC:                         3.334e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0839      0.033      2.511      0.012       0.018       0.149
# humidity                 0.1775      0.043      4.133      0.000       0.093       0.262
# windspeed                0.0905      0.002     36.797      0.000       0.086       0.095
# wind_hum_interaction    -0.2971      0.003    -88.470      0.000      -0.304      -0.291
# ==============================================================================
# Omnibus:                     4849.937   Durbin-Watson:                   0.265
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             9295.404
# Skew:                          -0.378   Prob(JB):                         0.00
# Kurtosis:                       4.320   Cond. No.                         193.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# All of the coefficients are still statistically significant at the p < 0.01 level.
#
# The signs of the humidity and windspeed coefficients are now positive.  The interaction variable has a negative sign and a larger magnitude than either of the individual coefficients.
#
# For a given windspeed, a 1 point increase in humidity has a .17-0.3X windspeed point change in the target variable.  For a given humidity, a one point increase in windspeed results in a 0.09-0.3X humidity point change in the target.

# %% [markdown]
# ###  3. House prices model
#
# In this exercise, you'll interpret your house prices model. To complete this assignment, submit a link to a Jupyter notebook containing your solutions to the following tasks:
#
# * Load the **houseprices** data from Thinkful's database.
# * Run your house prices model again and interpret the results. Which features are statistically significant, and which are not?
# * Now, exclude the insignificant features from your model. Did anything change?
# * Interpret the statistically significant coefficients by quantifying their relations with the house prices. Which features have a more prominent effect on house prices?
# * Do the results sound reasonable to you? If not, try to explain the potential reasons.

# %% [markdown]
# ### Answer 3:
#
# Will do when I finish the houseprices assignment.  TBD.
